# %%
import numpy as np
import pandas as pd
import os
import gc

import keras as k

import matplotlib.pyplot as plt
import cv2
from tqdm import tqdm
from multiprocessing import Pool, cpu_count
# Out:
# Using TensorFlow backend.

# %%
# %matplotlib inline

# %%
np.empty((1, 256, 256, 3), dtype=np.float16).nbytes * 40000 / (1024*1024)
# Out:
# 15000.0

# %% [markdown]
# # 1. Data Preprocessing

# %%
img_height = 64
img_width  = 64

# %%
df_train = pd.read_csv('../input/train_v2.csv')

flatten = lambda l: [item for sublist in l for item in sublist]
labels = list(set(flatten([l.split(' ') for l in df_train['tags'].values])))

label_map = {l: i for i, l in enumerate(labels)}
inv_label_map = {i: l for l, i in label_map.items()}

Y = np.empty((df_train.shape[0], 17), dtype=np.uint8)
i=0
for tags in tqdm(df_train['tags'].values, miniters=1000):
    targets = np.zeros(17)
    for t in tags.split(' '):
        targets[label_map[t]] = 1 
    Y[i,:] = targets
    i += 1
print(Y.shape)    

def get_images(names):
    i = 0
    X = np.empty((names.shape[0], img_height, img_width, 3), dtype=np.float16)
    for f in tqdm(names.values, miniters=1000):
        img = cv2.imread('../input/train-jpg/{}.jpg'.format(f))
        if img_height != img.shape[0]:
            img = cv2.resize(img, (img_height, img_width))
        X[i,:,:,:] = np.array(img, np.float16)
        i += 1
    return X / 255.

#multiply cpu_count if cannot fit memory
pool = Pool(cpu_count())
X = np.concatenate(pool.map(
    get_images, 
    np.array_split(df_train['image_name'], cpu_count())
))
pool.close()
pool.join()
print(X.shape)
# Out:
# 100%|██████████| 40479/40479 [00:00<00:00, 269305.93it/s]
# (40479, 17)
# 100%|██████████| 10120/10120 [00:29<00:00, 342.81it/s]
# 100%|██████████| 10120/10120 [00:29<00:00, 341.77it/s]
# 100%|██████████| 10119/10119 [00:29<00:00, 340.09it/s]
# 100%|██████████| 10120/10120 [00:29<00:00, 339.73it/s]
# (40479, 64, 64, 3)

# %%
plt.figure(figsize=(12,8))
for i in range(6):
    plt.subplot(2,3,i+1)
    plt.imshow(plt.imread('../input/train-jpg/train_{}.jpg'.format(i)))
    plt.title(str(df_train.loc[i].tags))

# %%
inv_label_map
# Out:
# {0: 'blooming',
#  1: 'partly_cloudy',
#  2: 'blow_down',
#  3: 'road',
#  4: 'bare_ground',
#  5: 'agriculture',
#  6: 'habitation',
#  7: 'slash_burn',
#  8: 'artisinal_mine',
#  9: 'cloudy',
#  10: 'clear',
#  11: 'conventional_mine',
#  12: 'haze',
#  13: 'water',
#  14: 'cultivation',
#  15: 'selective_logging',
#  16: 'primary'}

# %% [markdown]
# # 2. Model Building

# %%
from sklearn.model_selection import train_test_split

# %%
split = 35000
#x_train, x_valid, y_train, y_valid = X[:split], X[split:], Y[:split], Y[split:]
x_train, x_valid, y_train, y_valid = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
from keras import backend as K
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import Adam

# %%
def fbeta(y_true, y_pred):
    beta = 2
    threshold_shift = -0.3

    # just in case of hipster activation at the final layer
    y_pred = K.clip(y_pred, 0, 1)

    # shifting the prediction threshold from .5 if needed
    y_pred_bin = K.round(y_pred + threshold_shift)

    tp = K.sum(K.round(y_true * y_pred_bin), axis=1) + K.epsilon()
    fp = K.sum(K.round(K.clip(y_pred_bin - y_true, 0, 1)), axis=1)
    fn = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=1)

    precision = tp / (tp + fp)
    recall = tp / (tp + fn)

    beta_squared = beta ** 2
    return K.mean((beta_squared + 1) * (precision * recall) / (beta_squared * precision + recall + K.epsilon()))

# %%
model = Sequential()
model.add(BatchNormalization(input_shape=(64, 64,3)))
model.add(Conv2D(32, kernel_size=(3, 3),padding='same', activation='relu'))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size=(3, 3),padding='same', activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, kernel_size=(3, 3),padding='same', activation='relu'))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(256, kernel_size=(3, 3),padding='same', activation='relu'))
model.add(Conv2D(256, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(17, activation='sigmoid'))

# %%
epochs_arr = [20, 5, 5]
learn_rates = [0.001, 0.0001, 0.00001]
kfold_weights_path = os.path.join('', 'weights.h5')

for learn_rate, epochs in zip(learn_rates, epochs_arr):
    opt  = Adam(lr=learn_rate)
    model.compile(loss='binary_crossentropy', # We NEED binary here, since categorical_crossentropy l1 norms the output before calculating loss.
                  optimizer=opt,
                  metrics=['accuracy', fbeta])
    callbacks = [
        EarlyStopping(monitor='val_loss', patience=2, verbose=2),
        ModelCheckpoint(kfold_weights_path, monitor='val_loss', 
                        save_best_only=True, verbose=2)
    ]

    model.fit(x = x_train, y= y_train, validation_data=(x_valid, y_valid),
          batch_size=128,verbose=1, epochs=epochs,callbacks=callbacks,shuffle=True)
# Out:
# Train on 32383 samples, validate on 8096 samples
# Epoch 1/20
# Epoch 00000: val_loss improved from inf to 0.25578, saving model to weights.h5
# 32383/32383 [==============================] - 45s - loss: 0.2742 - acc: 0.9003 - fbeta: 0.6265 - val_loss: 0.2558 - val_acc: 0.9065 - val_fbeta: 0.6438
# Epoch 2/20
# Epoch 00001: val_loss improved from 0.25578 to 0.19443, saving model to weights.h5
# 32383/32383 [==============================] - 46s - loss: 0.1636 - acc: 0.9347 - fbeta: 0.7488 - val_loss: 0.1944 - val_acc: 0.9211 - val_fbeta: 0.6687
# Epoch 3/20
# Epoch 00002: val_loss improved from 0.19443 to 0.14676, saving model to weights.h5
# 32383/32383 [==============================] - 45s - loss: 0.1528 - acc: 0.9386 - fbeta: 0.7697 - val_loss: 0.1468 - val_acc: 0.9403 - val_fbeta: 0.7381
# Epoch 4/20
# Epoch 00003: val_loss improved from 0.14676 to 0.13732, saving model to weights.h5
# 32383/32383 [==============================] - 45s - loss: 0.1458 - acc: 0.9416 - fbeta: 0.7848 - val_loss: 0.1373 - val_acc: 0.9448 - val_fbeta: 0.8241
# Epoch 5/20
# Epoch 00004: val_loss improved from 0.13732 to 0.13050, saving model to weights.h5
# 32383/32383 [==============================] - 44s - loss: 0.1406 - acc: 0.9439 - fbeta: 0.7960 - val_loss: 0.1305 - val_acc: 0.9482 - val_fbeta: 0.8107
# Epoch 6/20
# Epoch 00005: val_loss improved from 0.13050 to 0.12640, saving model to weights.h5
# 32383/32383 [==============================] - 44s - loss: 0.1350 - acc: 0.9467 - fbeta: 0.8103 - val_loss: 0.1264 - val_acc: 0.9490 - val_fbeta: 0.8238
# Epoch 7/20
# Epoch 00006: val_loss did not improve
# 32383/32383 [==============================] - 43s - loss: 0.1325 - acc: 0.9479 - fbeta: 0.8144 - val_loss: 0.1315 - val_acc: 0.9475 - val_fbeta: 0.7923
# Epoch 8/20
# Epoch 00007: val_loss improved from 0.12640 to 0.11876, saving model to weights.h5
# 32383/32383 [==============================] - 44s - loss: 0.1292 - acc: 0.9491 - fbeta: 0.8212 - val_loss: 0.1188 - val_acc: 0.9536 - val_fbeta: 0.8401
# Epoch 9/20
# Epoch 00008: val_loss improved from 0.11876 to 0.11784, saving model to weights.h5
# 32383/32383 [==============================] - 44s - loss: 0.1255 - acc: 0.9509 - fbeta: 0.8316 - val_loss: 0.1178 - val_acc: 0.9543 - val_fbeta: 0.8494
# Epoch 10/20
# Epoch 00009: val_loss did not improve
# 32383/32383 [==============================] - 44s - loss: 0.1224 - acc: 0.9523 - fbeta: 0.8369 - val_loss: 0.1184 - val_acc: 0.9534 - val_fbeta: 0.8255
# Epoch 11/20
# Epoch 00010: val_loss did not improve
# 32383/32383 [==============================] - 44s - loss: 0.1215 - acc: 0.9525 - fbeta: 0.8373 - val_loss: 0.1211 - val_acc: 0.9524 - val_fbeta: 0.8380
# Epoch 12/20
# Epoch 00011: val_loss improved from 0.11784 to 0.11443, saving model to weights.h5
# 32383/32383 [==============================] - 44s - loss: 0.1198 - acc: 0.9533 - fbeta: 0.8418 - val_loss: 0.1144 - val_acc: 0.9560 - val_fbeta: 0.8448
# Epoch 13/20
# Epoch 00012: val_loss improved from 0.11443 to 0.11085, saving model to weights.h5
# 32383/32383 [==============================] - 44s - loss: 0.1178 - acc: 0.9539 - fbeta: 0.8451 - val_loss: 0.1108 - val_acc: 0.9568 - val_fbeta: 0.8508
# Epoch 14/20
# Epoch 00013: val_loss did not improve
# 32383/32383 [==============================] - 44s - loss: 0.1174 - acc: 0.9544 - fbeta: 0.8455 - val_loss: 0.1123 - val_acc: 0.9559 - val_fbeta: 0.8522
# Epoch 15/20
# Epoch 00014: val_loss did not improve
# 32383/32383 [==============================] - 44s - loss: 0.1155 - acc: 0.9551 - fbeta: 0.8492 - val_loss: 0.1116 - val_acc: 0.9568 - val_fbeta: 0.8529
# Epoch 16/20
# Epoch 00015: val_loss did not improve
# 32383/32383 [==============================] - 44s - loss: 0.1138 - acc: 0.9558 - fbeta: 0.8511 - val_loss: 0.1109 - val_acc: 0.9571 - val_fbeta: 0.8553
# Epoch 00015: early stopping
# Train on 32383 samples, validate on 8096 samples
# Epoch 1/5
# Epoch 00000: val_loss improved from inf to 0.10582, saving model to weights.h5
# 32383/32383 [==============================] - 44s - loss: 0.1056 - acc: 0.9591 - fbeta: 0.8661 - val_loss: 0.1058 - val_acc: 0.9589 - val_fbeta: 0.8636
# Epoch 2/5
# Epoch 00001: val_loss improved from 0.10582 to 0.10507, saving model to weights.h5
# 32383/32383 [==============================] - 44s - loss: 0.1029 - acc: 0.9598 - fbeta: 0.8697 - val_loss: 0.1051 - val_acc: 0.9593 - val_fbeta: 0.8659
# Epoch 3/5
# Epoch 00002: val_loss improved from 0.10507 to 0.10456, saving model to weights.h5
# 32383/32383 [==============================] - 44s - loss: 0.1018 - acc: 0.9605 - fbeta: 0.8722 - val_loss: 0.1046 - val_acc: 0.9595 - val_fbeta: 0.8672
# Epoch 4/5
# Epoch 00003: val_loss improved from 0.10456 to 0.10397, saving model to weights.h5
# 32383/32383 [==============================] - 44s - loss: 0.1008 - acc: 0.9607 - fbeta: 0.8725 - val_loss: 0.1040 - val_acc: 0.9598 - val_fbeta: 0.8689
# Epoch 5/5
# Epoch 00004: val_loss did not improve
# 32383/32383 [==============================] - 44s - loss: 0.1006 - acc: 0.9609 - fbeta: 0.8743 - val_loss: 0.1047 - val_acc: 0.9596 - val_fbeta: 0.8670
# Train on 32383 samples, validate on 8096 samples
# Epoch 1/5
# Epoch 00000: val_loss improved from inf to 0.10386, saving model to weights.h5
# 32383/32383 [==============================] - 44s - loss: 0.0995 - acc: 0.9615 - fbeta: 0.8756 - val_loss: 0.1039 - val_acc: 0.9600 - val_fbeta: 0.8701
# Epoch 2/5
# Epoch 00001: val_loss improved from 0.10386 to 0.10373, saving model to weights.h5
# 32383/32383 [==============================] - 45s - loss: 0.0985 - acc: 0.9615 - fbeta: 0.8762 - val_loss: 0.1037 - val_acc: 0.9601 - val_fbeta: 0.8697
# Epoch 3/5
# Epoch 00002: val_loss improved from 0.10373 to 0.10368, saving model to weights.h5
# 32383/32383 [==============================] - 43s - loss: 0.0991 - acc: 0.9613 - fbeta: 0.8755 - val_loss: 0.1037 - val_acc: 0.9602 - val_fbeta: 0.8689
# Epoch 4/5
# Epoch 00003: val_loss did not improve
# 32383/32383 [==============================] - 44s - loss: 0.0986 - acc: 0.9614 - fbeta: 0.8753 - val_loss: 0.1037 - val_acc: 0.9601 - val_fbeta: 0.8692
# Epoch 5/5
# Epoch 00004: val_loss improved from 0.10368 to 0.10364, saving model to weights.h5
# 32383/32383 [==============================] - 44s - loss: 0.0987 - acc: 0.9612 - fbeta: 0.8754 - val_loss: 0.1036 - val_acc: 0.9602 - val_fbeta: 0.8705

# %%
from sklearn.metrics import fbeta_score, accuracy_score

# %%
if os.path.isfile(kfold_weights_path):
    model.load_weights(kfold_weights_path)

# %%
p_valid = model.predict(x_valid, batch_size=128, verbose=1)
# Out:
# 8096/8096 [==============================] - 3s

# %%
print(fbeta_score(y_valid, np.array(p_valid) > 0.16, beta=2, average='samples'))
# Out:
# 0.912473230662

# %%
score = fbeta_score(y_valid, np.array(p_valid) > 0.2, beta=2, average=None)
print('F2 test scores per tag:')
[(inv_label_map[l], score[l]) for l in score.argsort()[::-1]]
# Out:
# F2 test scores per tag:
# /home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [('primary', 0.9904487247327759),
#  ('clear', 0.97583707283396637),
#  ('partly_cloudy', 0.92655908096280104),
#  ('cloudy', 0.88376560999039389),
#  ('agriculture', 0.8780657103192967),
#  ('road', 0.81247754759908986),
#  ('haze', 0.75657894736842113),
#  ('water', 0.73514144822216454),
#  ('artisinal_mine', 0.65934065934065922),
#  ('habitation', 0.6344601412714429),
#  ('cultivation', 0.63124617581072817),
#  ('bare_ground', 0.27744982290436837),
#  ('selective_logging', 0.24561403508771931),
#  ('blooming', 0.019230769230769232),
#  ('slash_burn', 0.0),
#  ('conventional_mine', 0.0),
#  ('blow_down', 0.0)]

# %%
blow_down = p_valid
for i in np.arange(0.1,0.2,0.01):
    print(i, '\t:', accuracy_score(y_valid, blow_down>i))
    #print(i, '\t:', fbeta_score(y_valid, blow_down > i, beta=2, average='samples'))
#pd.Series(p_valid[y_valid[2]==1][2]).describe()
# Out:
# 0.1 	: 0.436511857708
# 0.11 	: 0.447504940711
# 0.12 	: 0.458992094862
# 0.13 	: 0.469738142292
# 0.14 	: 0.479866600791
# 0.15 	: 0.48851284585
# 0.16 	: 0.499505928854
# 0.17 	: 0.507164031621
# 0.18 	: 0.512475296443
# 0.19 	: 0.518404150198

# %%
thres = 0.16

# %% [markdown]
# # 3. Make Prediction

# %%
df_submission = pd.read_csv('../input/sample_submission_v2.csv')

def get_images(names):
    i = 0
    X = np.empty((names.shape[0], img_height, img_width, 3), dtype=np.float16)
    for f in tqdm(names.values, miniters=1000):
        img = cv2.imread('../input/test-jpg/{}.jpg'.format(f))
        if img_height != img.shape[0]:
            img = cv2.resize(img, (img_height, img_width))
        X[i,:,:,:] = np.array(img, np.float16)
        i += 1
    return X / 255.

pool = Pool(cpu_count())
X_submission = np.concatenate(pool.map(
    get_images, 
    np.array_split(df_submission['image_name'], cpu_count())
))
pool.close()
pool.join()
print(X_submission.shape)

# %%
predict = model.predict(X_submission, batch_size = 128, verbose=1)

# %%
result = pd.DataFrame(np.zeros((df_submission.shape[0], 17)))
result[1] = 1
result[10] = 1
preds = []
sorted_tags = pd.Series(inv_label_map)

for i in tqdm(range(result.shape[0]), miniters=1000):
    preds.append(' '.join(list(
        sorted_tags[np.where(result.loc[i] == 1)[0]]
    )))

# %%
df_submission['tags'] = preds
df_submission.to_csv('submission#.csv', index=False)
